# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
file_two = "Resources/Copy of 98-400-X2016008_English_CSV_data.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")

# %%
# Show just the header
file_two_df.head()
# Out:
#    ï»¿CENSUS_YEAR GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  DATA_QUALITY_FLAG  \
# 0            2016              1          0   Canada  4.0              20000
# 1            2016            A0A          2      A0A  4.2                  0
# 2            2016            A0B          2      A0B  4.1                  0
# 3            2016            A0C          2      A0C  4.1                  0
# 4            2016            A0E          2      A0E  4.2                  0
#
#   ALT_GEO_CODE DIM: Age (in single years) and average age (127)  \
# 0            1                                      Average age
# 1        01A0A                                      Average age
# 2        01A0B                                      Average age
# 3        01A0C                                      Average age
# 4        01A0E                                      Average age
#
#    Member ID: Age (in single years) and average age (127)  \
# 0                                                127
# ...

# %%
file_two_df = file_two_df.reindex(sorted(file_two_df.columns), axis=1)

# %%
# Show a single column
file_two_df.head()
# Out:
#   ALT_GEO_CODE  DATA_QUALITY_FLAG  \
# 0            1              20000
# 1        01A0A                  0
# 2        01A0B                  0
# 3        01A0C                  0
# 4        01A0E                  0
#
#   DIM: Age (in single years) and average age (127)  \
# 0                                      Average age
# 1                                      Average age
# 2                                      Average age
# 3                                      Average age
# 4                                      Average age
#
#    Dim: Sex (3): Member ID: [1]: Total - Sex  \
# 0                                       41.0
# 1                                       44.9
# 2                                       49.3
# 3                                       48.8
# 4                                       47.0
#
#    Dim: Sex (3): Member ID: [2]: Male  Dim: Sex (3): Member ID: [3]: Female  \
# 0                                40.1                                  41.9
# ...

# %%
#df.sort_values(by=['FSA'])
postal_code = file_two_df[["GEO_NAME", "Dim: Sex (3): Member ID: [1]: Total - Sex"]]
postal_code
# Out:
#      GEO_NAME  Dim: Sex (3): Member ID: [1]: Total - Sex
# 0      Canada                                       41.0
# 1         A0A                                       44.9
# 2         A0B                                       49.3
# 3         A0C                                       48.8
# 4         A0E                                       47.0
# ...       ...                                        ...
# 1616      X0G                                       34.9
# 1617      X1A                                       34.8
# 1618      Y0A                                       41.8
# 1619      Y0B                                       42.0
# 1620      Y1A                                       38.3
#
# [1621 rows x 2 columns]

# %%
#for x in postal_code["FSA"]:
  #print(x[0])
postal_code = postal_code.dropna(how='any',axis=0) 
postal_code[postal_code["GEO_NAME"].str.startswith('M')]
##ALT_GEO_CODE
# Out:
#     GEO_NAME  Dim: Sex (3): Member ID: [1]: Total - Sex
# 885      M1B                                       38.9
# 886      M1C                                       42.1
# 887      M1E                                       41.5
# 888      M1G                                       38.6
# 889      M1H                                       39.9
# ..       ...                                        ...
# 976      M9N                                       39.3
# 977      M9P                                       44.9
# 978      M9R                                       40.9
# 979      M9V                                       37.4
# 980      M9W                                       39.6
#
# [96 rows x 2 columns]
